# %%
#import functions
import pandas as pd
import numpy as np
import os, sys
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
#import iris dataset
from sklearn.datasets import load_iris
iris = load_iris()

#convert the bunch object to a dataframe
iris_df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])

#convert dataframe to numpy array
iris_np = np.array(iris_df)

#make seperate objects for predictors / target
X = iris_np[:,:-1]
y = iris_np[:,4].astype(int)

#we can think of X as matric with dimension M x N, with M observations and N features
#we can think of Y as a vector with M targets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.25,
                                                    random_state=1234,
                                                    stratify=y)

from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(X_train, y_train)

prediction = classifier.predict(X_test)
probs = classifier.predict_proba(X_test)

# %%
#make objects
df = pd.read_csv("../data/churn.csv")
df = df.drop(["Phone", "Area Code", "State"], axis=1)
X = df.drop(["Churn"], axis=1)
y = df['Churn'].values.tolist()

# Split the data into test and training (30% for test)
X_train, X_test, Y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state = 123)

# Instantiate the classifier
clf = LogisticRegression()

# Train the classifier using the train data
clf = clf.fit(X_train, Y_train)

prediction = clf.predict(X_test)

probs = clf.predict_proba(X_test)

# %%
import evaluation_model
reload(evaluation_model)
#iris.target_names
dct = evaluation_model.evaluate_supervised_learning_model_classification(y_test, prediction, probs, None)
# Out:
# - Accuracy is: 86.9%
#
# Confusion Matrix:
# -----------------
# Confusion Matrix Numbers and Rates:
# -----------------------------------
# TP: 28
# FN: 106
# TN: 841
# FP: 25
# TPR: 20.9 %
# FNR: 79.1 %
# TNR: 97.11 %
# FPR: 2.89 %
#
# Precision, Recall and F1-score:
# -------------------------------
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93       866
#           1       0.53      0.21      0.30       134
#
# avg / total       0.84      0.87      0.84      1000
#
# ROC-Curve:
# ----------

# %%
x = X_test.copy()
y = y_test
obs_to_plot = dct['class_wrong'].copy()
features = [0, 2]

# %%
import evaluation_model
reload(evaluation_model)
evaluation_model.plot_label_with_two_numerical_features(x, y, features, y_labels = None, 
                                       obs_to_plot = obs_to_plot,
                                      plot_both = True)

# %%
plot_label_with_two_numerical_features(x, y, features, y_labels = iris.target_names, 
                                       obs_to_plot = obs_to_plot,
                                      plot_both = True)

# %%
#this creates the toy data for the rest of the excercise
n_obs = 100
x = np.linspace(-3, 3, n_obs)
y = x + x*np.random.normal(2,.5,n_obs)
print('Before: ', x.shape)
X = x[:, np.newaxis]
print('After: ', X.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
# Out:
# ('Before: ', (100,))
# ('After: ', (100, 1))

# %%
import evaluation_model
reload(evaluation_model)
evaluation_model.evaluate_supervised_learning_model_regression(y_test, y_pred, info = True)
# Out:
# Explained variance score: 0.9778231464339349
# R2 score: 0.97768313363265
# Mean squared error: 0.6168352489187613
# Mean Squared Logarithmic Error cannot be used when targets contain negative values.
# Mean absolute error: 0.5876008523086199
# Median absolute error: 0.40211330882174057

# %%
y_pred
# Out:
# array([ 6.04826344,  0.62130665,  3.69658216, -0.82588183, -1.00678039,
#        -1.91127319, -4.98654871,  5.50556776, -7.15733143, -8.96631703,
#        -5.71014295, -3.53936023,  4.23927784, -2.99666455,  7.31455336,
#        -8.24272279,  4.78197352,  4.96287208, -6.79553431, -3.35846167,
#         0.98310377,  6.95275624, -4.26295447, -1.36857751,  3.5156836 ])
